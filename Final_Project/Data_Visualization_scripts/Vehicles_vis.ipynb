# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',200)
import warnings
warnings.filterwarnings('ignore')

# %%
vdata = pd.read_csv('/Users/sonalibandi/Documents/DMDD/vehicles_f.csv', index_col=False, delimiter = ',')

# %%
vdata
# Out:
#                  Name      CrashName Sex  Age   VehicleDamage PartyCategory  \
# 0      ACV-0000174429  CR-0000085218   M   19           Major        Driver
# 1      ACV-0000174443  CR-0000085224   F   43           Minor        Driver
# 2      ACV-0000174444  CR-0000085224   F   51           Minor        Driver
# 3      ACV-0000174445  CR-0000085225   M   21        Moderate        Driver
# 4      ACV-0000174446  CR-0000085225   M   53           Major        Driver
# ...               ...            ...  ..  ...             ...           ...
# 50348  ACV-0000175292  CR-0000084623   M   32        Moderate        Driver
# 50349  ACV-0000175293  CR-0000084623   M   32        Moderate        Driver
# 50350  ACV-0000175754  CR-0000085886   F   21  Not Applicable    Pedestrian
# 50351  ACV-0000175867  CR-0000085939   F   26        Moderate        Driver
# 50352  ACV-0000175868  CR-0000085939   M   35        Moderate        Driver
#
# ...

# %%
vdata.describe()
# Out:
#                 Age
# count  50353.000000
# mean      38.351280
# std       15.841438
# min       18.000000
# 25%       26.000000
# 50%       35.000000
# 75%       49.000000
# max       99.000000

# %%
vdata.count()
# Out:
# Name                          50353
# CrashName                     50353
# Sex                           50353
# Age                           50353
# VehicleDamage                 50353
# PartyCategory                 50353
# Sobriety                      50353
# VehicleDirection              50353
# MovementPrecedingCollision    50353
# ViolationCode                 50353
# dtype: int64

# %%
import matplotlib.pyplot as plt
def plot_nas(vdata: pd.DataFrame):
    if vdata.isnull().sum().sum() != 0:
        na_df = (df.isnull().sum() / len(df)) * 100      
        na_df = na_df.drop(na_df[na_df == 0].index).sort_values(ascending=False)
        missing_data = pd.DataFrame({'Missing Ratio %' :na_df})
        missing_data.plot(kind = "barh")
        plt.show()
    else:
        print('No NAs found')
plot_nas(vdata)
# Out:
# No NAs found

# %%
def bivariate_cat_cat(variable,var_hue):
    plt.figure(figsize=(20, 10))
    sns.countplot(variable,hue=var_hue, data=vdata, palette= 'bright', order= vdata[variable].value_counts().index, hue_order=vdata[var_hue].value_counts().index)
    plt.title('Analysis of '+ '%s' %variable , weight='heavy', fontsize=15)
    plt.xlabel(variable)
    plt.ylabel(var_hue)
    plt.legend(loc='upper right')
    
    plt.show()

# %%
bivariate_cat_cat('VehicleDamage', 'Sobriety')
