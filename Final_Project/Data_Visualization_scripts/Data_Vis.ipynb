# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas.testing as tm
from scipy import stats
import seaborn as sns
from sklearn.datasets import load_boston

# Make plots larger
plt.rcParams['figure.figsize'] = (15, 9)

# %%
fdata = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Vehicles_f.csv', index_col=False, delimiter = ',')

# %%
fdata['Age'].value_counts()
# Out:
# 26    6653
# 35    2360
# 23    1391
# 22    1381
# 21    1347
#       ...
# 98       8
# 95       6
# 97       5
# 99       2
# 96       2
# Name: Age, Length: 82, dtype: int64

# %%
sns.boxplot(x=fdata["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
fdata['VehicleDamage'].hist(bins=33)
# Out:
# <AxesSubplot:>
