# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',200)
import warnings
warnings.filterwarnings('ignore')

# %%
col_names = ['Name','Distance', 'PedestrianAction','PrimaryCollisionFactor', 'CollisionType', 'ProximityToIntersection', 'VehicleInvolvedWith']

# %%
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/crashes_final.csv', names=col_names)

# %%
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 46653  CR-0000049048        29                  No Pedestrians Involved
# 46654  CR-0000049690       109                  No Pedestrians Involved
# 46655  CR-0000049601       201                  No Pedestrians Involved
# 46656  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 46657  CR-0000085939        51                  No Pedestrians Involved
#
#        PrimaryCollisionFactor       CollisionType  ProximityToIntersection  \
# ...

# %%
def bivariate_cat_cat(variable,var_hue):
    plt.figure(figsize=(20, 10))
    sns.countplot(variable,hue=var_hue, data=df, palette= 'bright', order= df[variable].value_counts().index, hue_order=df[var_hue].value_counts().index)
    plt.title('Analysis of '+ '%s' %variable , weight='heavy', fontsize=15)
    plt.xlabel(variable)
    plt.ylabel(var_hue)
    plt.legend(loc='upper right')
    
    plt.show()

# %%
bivariate_cat_cat('CollisionType', 'VehicleInvolvedWith')
