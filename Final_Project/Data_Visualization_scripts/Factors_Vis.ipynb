# %%
#Installs MySQL connector module
import pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

# %%
from venv import create
import csv
import pandas as pd
import os
import time
import numpy as np

# %%
#The connect() constructor creates a connection to the MySQL server and returns a MySQLConnection object. 
import mysql.connector
import pandas as pd
fdata = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_table_final.csv', index_col=False, delimiter = ',')
fdata.head()
# Out:
#        CrashName TimeStamp Weather RoadwaySurface       RoadwayCondition  \
# 0  CR-0000089828   2/19/22   Clear            Dry  No Unusual Conditions
# 1  CR-0000090339    4/7/22   Clear            Dry  No Unusual Conditions
# 2  CR-0000090341   4/16/22    Rain            Wet  No Unusual Conditions
# 3  CR-0000090539    3/2/22   Clear            Dry  No Unusual Conditions
# 4  CR-0000090540    5/4/22   Clear            Dry  No Unusual Conditions
#
#                  Lighting
# 0  Dark - No Street Light
# 1                Daylight
# 2     Dark - Street Light
# 3                Daylight
# 4     Dark - Street Light

# %%
fdata.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#plot() is a convenience to plot 'year' 'CrashName' of the columns with labels:
fdata.groupby('year')['CrashName'].count().plot(kind = 'bar',figsize = (25,8))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#plot() is a convenience to plot 'Weather' 'CrashName' of the columns with labels:
fdata.groupby('Weather')['CrashName'].count().plot(kind = 'pie',figsize = (8,8))
# Out:
# <AxesSubplot:ylabel='CrashName'>

# %%
#plot() is a convenience to plot 'RoadwayCondition' 'CrashName' of the columns with labels:
fdata.groupby('RoadwayCondition')['CrashName'].count().plot(kind = 'bar',figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='RoadwayCondition'>

# %%
#plot() is a convenience to plot 'Weather' 'CrashName' of the columns with labels:
fdata.groupby('Weather')['CrashName'].count().plot(kind = 'bar',figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Weather'>

# %%
#plot() is a convenience to plot 'month' 'CrashName' of the columns with labels:
fdata.groupby('month')['CrashName'].count().plot(kind = 'bar',figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='month'>
