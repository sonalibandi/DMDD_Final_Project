# %%
import pandas as pd
df=pd.read_csv('/Users/sonalibandi/Documents/DMDD/vehicles_table.csv',dtype={'Name': 'str', 'CrashName': 'str', 'Sex': 'str', 'Age': 'str', 'VehicleDamage': 'str', 'PartyCategory': 'str', 'Sobriety': 'str', 'VehicleDirection': 'str', 'MovementPrecedingCollision': 'str'})

# %%
col_names = ['Name','CrashName', 'Sex', 'Age', 'VehicleDamage', 'PartyCategory', 'Sobriety', 'VehicleDirection', 'MovementPrecedingCollision']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/vehicles_table.csv', header=None, names=col_names, dtype={'Name': 'str', 'CrashName': 'str', 'Sex': 'str', 'Age': 'str', 'VehicleDamage': 'str', 'PartyCategory': 'str', 'Sobriety': 'str', 'VehicleDirection': 'str', 'MovementPrecedingCollision': 'str'} )

# %%
#The ffill() method replaces the NULL values with the value from the previous row in Gender column
df2=df.fillna(method='ffill')
df2
# Out:
#                   Name      CrashName  Sex  Age  VehicleDamage  PartyCategory  \
# 0                 Name      CrashName  Sex  Age  VehicleDamage  PartyCategory
# 1       ACV-0000174389  CR-0000085197    M   33        Unknown         Driver
# 2       ACV-0000174390  CR-0000085197    M    0        Unknown         Driver
# 3       ACV-0000174429  CR-0000085218    M   19          Major         Driver
# 4       ACV-0000174430  CR-0000085218    M    0       Moderate         Parked
# ...                ...            ...  ...  ...            ...            ...
# 131911  ACV-0000175866  CR-0000085938    F    0          Minor         Parked
# 131912  ACV-0000175865  CR-0000085938    M   28          Minor         Driver
# 131913  ACV-0000175868  CR-0000085939    M   35       Moderate         Driver
# 131914  ACV-0000178306  CR-0000087195    F   58        Unknown         Driver
# 131915  ACV-0000178305  CR-0000087195    M   29        Unknown         Driver
#
# ...

# %%
df2.to_csv('/Users/sonalibandi/Documents/DMDD/vehicles_draft.csv',index=True)
