# %%
import pandas as pd

# %%
col_names = ['Name','Distance', 'PedestrianAction', 'Lighting', 'PrimaryCollisionFactor', 'CollisionType', 'ProximityToIntersection', 'VehicleInvolvedWith']
df = pd.read_csv('/Users/sonalibandi/Desktop/Raw_Data/crashes_table.csv', header=None, names=col_names)

# %%
df["Distance"].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62936  CR-0000032506         0                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62939  CR-0000085938        95                  No Pedestrians Involved
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df = df.drop(df.index[df['Lighting'] == 'Unknown'])
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62936  CR-0000032506         0                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62939  CR-0000085938        95                  No Pedestrians Involved
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/crashes_draft_lighting.csv',index=False)

# %%
df.index[df['Lighting'] == 'Unknown']
# Out:
# Int64Index([    7,    42,    57,    58,    60,    76,    77,    80,   157,
#               177,
#             ...
#             61382, 61521, 61597, 61804, 61870, 61918, 62199, 62348, 62652,
#             62862],
#            dtype='int64', length=834)

# %%
df = df.query('Distance != "unknown"')

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/crashes_draft1.csv',index=False)

# %%
df = df.query('Distance != "unknown" ')

# %%
print(df1)
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62936  CR-0000032506         0                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62939  CR-0000085938        95                  No Pedestrians Involved
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df = df.drop(df.index[df['PedestrianAction'] == 'Unknown'])
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62936  CR-0000032506         0                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62939  CR-0000085938        95                  No Pedestrians Involved
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/crashes_draft2.csv',index=False)

# %%
df = df.drop(df.index[df['PrimaryCollisionFactor'] == 'Unknown'])
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62934  CR-0000049048        29                  No Pedestrians Involved
# 62935  CR-0000049690       109                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/crashes_draft3.csv',index=False)

# %%
df = df.drop(df.index[df['VehicleInvolvedWith'] == 'Unknown'])
df
# Out:
#                 Name  Distance                         PedestrianAction  \
# 0               Name  Distance                         PedestrianAction
# 1      CR-0000089828       800                  No Pedestrians Involved
# 2      CR-0000089850         0              Crossing - Not In Crosswalk
# 3      CR-0000090339         0  Crossing In Crosswalk - At Intersection
# 4      CR-0000090341         0                  No Pedestrians Involved
# ...              ...       ...                                      ...
# 62934  CR-0000049048        29                  No Pedestrians Involved
# 62935  CR-0000049690       109                  No Pedestrians Involved
# 62937  CR-0000049601       201                  No Pedestrians Involved
# 62938  CR-0000085886        24  Crossing In Crosswalk - At Intersection
# 62940  CR-0000085939        51                  No Pedestrians Involved
#
#                      Lighting  PrimaryCollisionFactor       CollisionType  \
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/crashes_final.csv',index=False)
