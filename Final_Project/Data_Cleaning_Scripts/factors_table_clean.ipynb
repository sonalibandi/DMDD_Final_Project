# %%
import pandas as pd

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_table.csv', header=None, names=col_names)

# %%
#drops UnKnown fields in Weather column
df = df.drop(df.index[df['Weather'] == 'Unknown'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 2      CR-0000089850    3/5/22 18:40    Clear         Unknown
# 3      CR-0000090339    4/7/22 18:26    Clear             Dry
# 5      CR-0000090341    4/16/22 4:15     Rain             Wet
# ...              ...             ...      ...             ...
# 64103  CR-0000049601   4/17/14 22:18    Clear             Dry
# 64104  CR-0000085886   2/27/20 14:19    Clear             Dry
# 64105  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 64106  CR-0000085938   2/29/20 20:29    Clear             Dry
# 64107  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 2      No Unusual Conditions     Dark - Street Light
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_1.csv',index=False)

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_1.csv', header=None, names=col_names)

# %%
#drops UnKnown fields in RoadwaySurface column
df = df.drop(df.index[df['RoadwaySurface'] == 'Unknown'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 3      CR-0000090339    4/7/22 18:26    Clear             Dry
# 4      CR-0000090341    4/16/22 4:15     Rain             Wet
# 5      CR-0000090539    3/2/22 16:45    Clear             Dry
# ...              ...             ...      ...             ...
# 62290  CR-0000049601   4/17/14 22:18    Clear             Dry
# 62291  CR-0000085886   2/27/20 14:19    Clear             Dry
# 62292  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 62293  CR-0000085938   2/29/20 20:29    Clear             Dry
# 62294  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 3      No Unusual Conditions                Daylight
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_2.csv',index=False)

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_2.csv', header=None, names=col_names)

# %%
#drops UnKnown fields in RoadwayCondition column
df = df.drop(df.index[df['RoadwayCondition'] == 'Unknown'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 2      CR-0000090339    4/7/22 18:26    Clear             Dry
# 3      CR-0000090341    4/16/22 4:15     Rain             Wet
# 4      CR-0000090539    3/2/22 16:45    Clear             Dry
# ...              ...             ...      ...             ...
# 61845  CR-0000049601   4/17/14 22:18    Clear             Dry
# 61846  CR-0000085886   2/27/20 14:19    Clear             Dry
# 61847  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 61848  CR-0000085938   2/29/20 20:29    Clear             Dry
# 61849  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 2      No Unusual Conditions                Daylight
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_3.csv',index=False)

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_3.csv', header=None, names=col_names)

# %%
#drops UnKnown fields in Lighting column
df = df.drop(df.index[df['Lighting'] == 'Unknown'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 2      CR-0000090339    4/7/22 18:26    Clear             Dry
# 3      CR-0000090341    4/16/22 4:15     Rain             Wet
# 4      CR-0000090539    3/2/22 16:45    Clear             Dry
# ...              ...             ...      ...             ...
# 60468  CR-0000049601   4/17/14 22:18    Clear             Dry
# 60469  CR-0000085886   2/27/20 14:19    Clear             Dry
# 60470  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 60471  CR-0000085938   2/29/20 20:29    Clear             Dry
# 60472  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 2      No Unusual Conditions                Daylight
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_4.csv',index=False)

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_4.csv', header=None, names=col_names)

# %%
#drops UnKnown fields in RoadwayCondition column
df = df.drop(df.index[df['RoadwayCondition'] == 'Other'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 2      CR-0000090339    4/7/22 18:26    Clear             Dry
# 3      CR-0000090341    4/16/22 4:15     Rain             Wet
# 4      CR-0000090539    3/2/22 16:45    Clear             Dry
# ...              ...             ...      ...             ...
# 60218  CR-0000049601   4/17/14 22:18    Clear             Dry
# 60219  CR-0000085886   2/27/20 14:19    Clear             Dry
# 60220  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 60221  CR-0000085938   2/29/20 20:29    Clear             Dry
# 60222  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 2      No Unusual Conditions                Daylight
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_5.csv',index=False)

# %%
col_names = ['CrashName','TimeStamp', 'Weather', 'RoadwaySurface', 'RoadwayCondition', 'Lighting']
df = pd.read_csv('/Users/sonalibandi/Documents/DMDD/Factors_5.csv', header=None, names=col_names)

# %%
#drops 'Other' fields in Weather column
df = df.drop(df.index[df['Weather'] == 'Other'])
df
# Out:
#            CrashName       TimeStamp  Weather  RoadwaySurface  \
# 0          CrashName       TimeStamp  Weather  RoadwaySurface
# 1      CR-0000089828    2/19/22 5:38    Clear             Dry
# 2      CR-0000090339    4/7/22 18:26    Clear             Dry
# 3      CR-0000090341    4/16/22 4:15     Rain             Wet
# 4      CR-0000090539    3/2/22 16:45    Clear             Dry
# ...              ...             ...      ...             ...
# 59981  CR-0000049601   4/17/14 22:18    Clear             Dry
# 59982  CR-0000085886   2/27/20 14:19    Clear             Dry
# 59983  CR-0000085936  12/26/20 18:31   Cloudy             Dry
# 59984  CR-0000085938   2/29/20 20:29    Clear             Dry
# 59985  CR-0000085939   9/18/20 19:30    Clear             Dry
#
#             RoadwayCondition                Lighting
# 0           RoadwayCondition                Lighting
# 1      No Unusual Conditions  Dark - No Street Light
# 2      No Unusual Conditions                Daylight
# ...

# %%
df.to_csv('/Users/sonalibandi/Documents/DMDD/Factors_final.csv',index=False)
